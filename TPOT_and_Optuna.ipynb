# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
df=pd.read_csv('data.csv')
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df=df.drop('Unnamed: 32',axis=1)
df
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302         M  ...          0.4601                  0.11890
# 1      842517         M  ...          0.2750                  0.08902
# 2    84300903         M  ...          0.3613                  0.08758
# 3    84348301         M  ...          0.6638                  0.17300
# 4    84358402         M  ...          0.2364                  0.07678
# ..        ...       ...  ...             ...                      ...
# 564    926424         M  ...          0.2060                  0.07115
# 565    926682         M  ...          0.2572                  0.06637
# 566    926954         M  ...          0.2218                  0.07820
# 567    927241         M  ...          0.4087                  0.12400
# 568     92751         B  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
df['diagnosis'].value_counts()

#B-benign and M-malignant
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df=df.drop('id',axis=1)
df
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           M        17.99  ...          0.4601                  0.11890
# 1           M        20.57  ...          0.2750                  0.08902
# 2           M        19.69  ...          0.3613                  0.08758
# 3           M        11.42  ...          0.6638                  0.17300
# 4           M        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564         M        21.56  ...          0.2060                  0.07115
# 565         M        20.13  ...          0.2572                  0.06637
# 566         M        16.60  ...          0.2218                  0.07820
# 567         M        20.60  ...          0.4087                  0.12400
# 568         B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
X=df.drop('diagnosis',axis=1)  #name is not useful
y=df['diagnosis']

# %%
#### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
param = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(param)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
# !pip install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.11.7-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 3.7 MB/s
# Collecting deap>=1.2
#   Downloading deap-1.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 16.2 MB/s
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.0.1)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.7/dist-packages (from tpot) (4.62.2)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.19.5)
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from tpot) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from tpot) (1.1.5)
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
#      |████████████████████████████████| 166.7 MB 14 kB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->tpot) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from update-checker>=0.16->tpot) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.24.3)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11952 sha256=1375f7a12f6ecc31ff88b04fa6bf571cabbc9fcbb6d742f54fd31d1d486c6589
#   Stored in directory: /root/.cache/pip/wheels/e2/d2/79/eaf81edb391e27c87f51b8ef901ecc85a5363dc96b8b8d71e3
# Successfully built stopit
# Installing collected packages: xgboost, update-checker, stopit, deap, tpot
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed deap-1.3.1 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0 xgboost-1.4.2

# %%
from tpot import TPOTClassifier


tpot_classifier = TPOTClassifier(generations= 5, population_size= 24, offspring_size= 12,
                                 verbosity= 2, early_stop= 12,
                                 config_dict={'sklearn.ensemble.RandomForestClassifier': param}, 
                                 cv = 4, scoring = 'accuracy')
tpot_classifier.fit(X_train,y_train)
# Out:
# Optimization Progress:   0%|          | 0/84 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9561209439528024
#
# Generation 2 - Current best internal CV score: 0.9561209439528024
#
# Generation 3 - Current best internal CV score: 0.9582945194845521
#
# Generation 4 - Current best internal CV score: 0.9582945194845521
#
# Generation 5 - Current best internal CV score: 0.9582945194845521
#
# Best pipeline: RandomForestClassifier(CombineDFs(input_matrix, input_matrix), criterion=entropy, max_depth=120, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1400)
# TPOTClassifier(config_dict={'sklearn.ensemble.RandomForestClassifier': {'criterion': ['entropy',
#                                                                                       'gini'],
#                                                                         'max_depth': [10,
#                                                                                       120,
#                                                                                       230,
#                                                                                       340,
#                                                                                       450,
#                                                                                       560,
#                                                                                       670,
#                                                                                       780,
#                                                                                       890,
#                                                                                       1000],
#                                                                         'max_features': ['auto',
#                                                                                          'sqrt',
#                                                                                          'log2'],
#                                                                         'min_samples_leaf': [1,
#                                                                                              2,
#                                                                                              4,
#                                                                                              6,
#                                                                                              8],
#                                                                         'min_samples_split': [2,
#                                                                                               5,
#                                                                                               10,
#                                                                                               14],
#                                                                         'n_estimators': [200,
#                                                                                          400,
#                                                                                          600,
#                                                                                          800,
#                                                                                          1000,
#                                                                                          1200,
#                                                                                          1400,
#                                                                                          1600,
#                                                                                          1800,
#                                                                                          2000]}},
#                crossover_rate=0.1, cv=4, disable_update_check=False,
#                early_stop=12, generations=5, log_file=None,
#                max_eval_time_mins=5, max_time_mins=None, memory=None,
#                mutation_rate=0.9, n_jobs=1, offspring_size=12,
#                periodic_checkpoint_folder=None, population_size=24,
#                random_state=None, scoring='accuracy', subsample=1.0,
#                template=None, use_dask=False, verbosity=2, warm_start=False)

# %%
rf_tpop=RandomForestClassifier(criterion='entropy', max_depth=120, max_features='auto', min_samples_leaf=2, min_samples_split=2, n_estimators=1400
                               )

# %%
rf_tpop.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=120, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1400,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
predictionforest = rf_tpop.predict(X_test)
print(confusion_matrix(y_test,predictionforest))
print(accuracy_score(y_test,predictionforest))
print(classification_report(y_test,predictionforest))
acc = accuracy_score(y_test,predictionforest)
# Out:
# [[65  2]
#  [ 2 45]]
# 0.9649122807017544
#               precision    recall  f1-score   support
#
#            B       0.97      0.97      0.97        67
#            M       0.96      0.96      0.96        47
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# Optuna

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.9.1-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 8.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.62.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.19.5)
# Collecting colorlog
#   Downloading colorlog-6.4.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.0)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.23)
# Collecting alembic
#   Downloading alembic-1.7.3-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 49.7 MB/s
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting cliff
#   Downloading cliff-3.9.0-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 9.6 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.8.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.2.2)
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.6 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.2.0)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.4.0-py3-none-any.whl (20 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.4.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.5 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.2.0-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 75.8 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.6.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 59.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (3.7.4.3)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.2.0)
# Collecting colorama>=0.3.7
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.5.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=ac22ff4807010758a7b3ffb35307c377c44c42e7f2d72c92555bdfd306118687
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, colorama, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.1.5 alembic-1.7.3 autopage-0.4.0 cliff-3.9.0 cmaes-0.8.2 cmd2-2.2.0 colorama-0.4.4 colorlog-6.4.1 optuna-2.9.1 pbr-5.6.0 pyperclip-1.8.2 stevedore-3.4.0

# %%
import optuna
import sklearn.svm
def objective(trial):

    classifier = trial.suggest_categorical('classifier', ['RandomForest', 'SVC'])
    
    if classifier == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 200, 2000,10)
        max_depth = int(trial.suggest_float('max_depth', 10, 100, log=True))

        clf = sklearn.ensemble.RandomForestClassifier(
            n_estimators=n_estimators, max_depth=max_depth)
    else:
        c = trial.suggest_float('svc_c', 1e-10, 1e10, log=True)
        
        clf = sklearn.svm.SVC(C=c, gamma='auto')

    return sklearn.model_selection.cross_val_score(
        clf,X_train,y_train, n_jobs=-1, cv=3).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial

print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2021-09-25 10:53:59,217] A new study created in memory with name: no-name-5f7fc12e-4042-4daa-9a14-341f64d67d83
# [I 2021-09-25 10:54:02,632] Trial 0 finished with value: 0.9384803067270826 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 18.100295711933573}. Best is trial 0 with value: 0.9384803067270826.
# [I 2021-09-25 10:54:07,144] Trial 1 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 960, 'max_depth': 22.559939711415584}. Best is trial 1 with value: 0.9450883002207506.
# [I 2021-09-25 10:54:09,197] Trial 2 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 440, 'max_depth': 33.22718292741932}. Best is trial 1 with value: 0.9450883002207506.
# [I 2021-09-25 10:54:09,254] Trial 3 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 30.22419147629482}. Best is trial 1 with value: 0.9450883002207506.
# [I 2021-09-25 10:54:13,804] Trial 4 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 980, 'max_depth': 71.0964108173387}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:20,886] Trial 5 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1540, 'max_depth': 23.18273349802339}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:20,937] Trial 6 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 0.00040750151453696485}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:20,991] Trial 7 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 1005100301.3502573}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:21,034] Trial 8 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 3.82058056276294e-06}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:23,388] Trial 9 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 15.353445198260413}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:32,287] Trial 10 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1920, 'max_depth': 91.84175189699779}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:39,334] Trial 11 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1530, 'max_depth': 53.20635230169482}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:45,027] Trial 12 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1230, 'max_depth': 38.096547930799176}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:49,750] Trial 13 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1020, 'max_depth': 10.000142251358783}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:54:57,060] Trial 14 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1580, 'max_depth': 93.21888606084741}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:03,428] Trial 15 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1370, 'max_depth': 53.702982045044294}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:12,031] Trial 16 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1860, 'max_depth': 55.7820367202674}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:15,716] Trial 17 finished with value: 0.9450737771581271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 790, 'max_depth': 27.830975998739316}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:15,759] Trial 18 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 1.2975663740217854e-10}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:18,789] Trial 19 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 640, 'max_depth': 12.849318282494623}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:19,926] Trial 20 finished with value: 0.9494597420704078 and parameters: {'classifier': 'RandomForest', 'n_estimators': 240, 'max_depth': 37.63054962928209}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:29,168] Trial 21 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 2000, 'max_depth': 10.473469347341071}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:34,883] Trial 22 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1240, 'max_depth': 99.73180275447068}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:38,189] Trial 23 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 710, 'max_depth': 16.6956070300342}. Best is trial 4 with value: 0.9494742651330311.
# [I 2021-09-25 10:55:41,760] Trial 24 finished with value: 0.9494887881956547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 770, 'max_depth': 13.420871299697195}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:55:44,975] Trial 25 finished with value: 0.9450737771581271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 690, 'max_depth': 13.361013376143243}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:55:45,037] Trial 26 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 2140002521.6330726}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:55:47,332] Trial 27 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 41.262913075041645}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:55:53,106] Trial 28 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1250, 'max_depth': 15.798143059256988}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:55:57,081] Trial 29 finished with value: 0.9472667596142674 and parameters: {'classifier': 'RandomForest', 'n_estimators': 850, 'max_depth': 20.5565211420536}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:00,064] Trial 30 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 640, 'max_depth': 11.466197733105457}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:04,111] Trial 31 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 870, 'max_depth': 27.16879444111501}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:09,230] Trial 32 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1110, 'max_depth': 22.210283886174008}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:12,355] Trial 33 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 670, 'max_depth': 12.594876714268704}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:19,845] Trial 34 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1630, 'max_depth': 18.54232067104282}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:22,397] Trial 35 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 550, 'max_depth': 15.162215427182666}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:24,021] Trial 36 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 340, 'max_depth': 13.651173487318879}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:24,078] Trial 37 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 2577.705679270264}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:24,133] Trial 38 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 68735.58746428696}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:27,914] Trial 39 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 810, 'max_depth': 69.54250655358746}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:33,269] Trial 40 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1150, 'max_depth': 17.332959354633562}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:37,684] Trial 41 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 950, 'max_depth': 24.942756435227235}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:40,987] Trial 42 finished with value: 0.9450737771581271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 700, 'max_depth': 18.71289737965942}. Best is trial 24 with value: 0.9494887881956547.
# [I 2021-09-25 10:56:42,769] Trial 43 finished with value: 0.9538747531079353 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 15.4148845494433}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:43,732] Trial 44 finished with value: 0.9494597420704078 and parameters: {'classifier': 'RandomForest', 'n_estimators': 200, 'max_depth': 21.869152715215318}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:45,540] Trial 45 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 15.413189028792644}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:47,327] Trial 46 finished with value: 0.9494887881956547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 33.05021039576138}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:49,093] Trial 47 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 370, 'max_depth': 12.610559568035617}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:49,137] Trial 48 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 6.585426479112056e-10}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:50,503] Trial 49 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 290, 'max_depth': 35.60062317378194}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:52,574] Trial 50 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 440, 'max_depth': 44.94307347018914}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:55,175] Trial 51 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 560, 'max_depth': 30.68864511517593}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:56:59,811] Trial 52 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1000, 'max_depth': 74.22343684684714}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:01,611] Trial 53 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 14.928307457685342}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:03,749] Trial 54 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 460, 'max_depth': 19.167987099468604}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:05,846] Trial 55 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 450, 'max_depth': 16.196463193263146}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:08,358] Trial 56 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 540, 'max_depth': 19.69923297635317}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:08,404] Trial 57 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 0.00015946859491111794}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:09,771] Trial 58 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 290, 'max_depth': 11.345369594704717}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:12,615] Trial 59 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 610, 'max_depth': 11.923555741901}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:16,186] Trial 60 finished with value: 0.945073777158127 and parameters: {'classifier': 'RandomForest', 'n_estimators': 770, 'max_depth': 14.176499488148965}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:22,745] Trial 61 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1410, 'max_depth': 17.092868952824794}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:29,451] Trial 62 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1440, 'max_depth': 31.74289390978216}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:35,536] Trial 63 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1320, 'max_depth': 48.361254026240154}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:43,539] Trial 64 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1740, 'max_depth': 10.383906428383492}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:44,829] Trial 65 finished with value: 0.945073777158127 and parameters: {'classifier': 'RandomForest', 'n_estimators': 270, 'max_depth': 11.222967740012145}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:46,923] Trial 66 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 450, 'max_depth': 35.8562617522416}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:49,086] Trial 67 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 460, 'max_depth': 26.8518263829855}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:51,820] Trial 68 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 590, 'max_depth': 36.12756748691961}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:55,324] Trial 69 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 750, 'max_depth': 16.548105189259918}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:57:55,376] Trial 70 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 0.5312371812664126}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:04,571] Trial 71 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 2000, 'max_depth': 14.318856615429189}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:11,216] Trial 72 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1430, 'max_depth': 12.96141142994366}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:12,712] Trial 73 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 320, 'max_depth': 11.169656602400606}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:15,207] Trial 74 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 530, 'max_depth': 15.235385478098836}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:23,634] Trial 75 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1830, 'max_depth': 17.40433891489525}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:25,500] Trial 76 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 84.00951502641713}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:28,470] Trial 77 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 640, 'max_depth': 40.87109489834519}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:32,760] Trial 78 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 920, 'max_depth': 12.449733104557923}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:38,311] Trial 79 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1200, 'max_depth': 20.555710232691805}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:39,323] Trial 80 finished with value: 0.9494887881956547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 210, 'max_depth': 39.865228716212144}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:40,796] Trial 81 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 310, 'max_depth': 65.21370110379647}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:41,752] Trial 82 finished with value: 0.9472958057395143 and parameters: {'classifier': 'RandomForest', 'n_estimators': 200, 'max_depth': 40.14094297414114}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:42,999] Trial 83 finished with value: 0.9428807947019867 and parameters: {'classifier': 'RandomForest', 'n_estimators': 260, 'max_depth': 60.8720556231006}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:46,409] Trial 84 finished with value: 0.947281282676891 and parameters: {'classifier': 'RandomForest', 'n_estimators': 730, 'max_depth': 29.34538247283774}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:48,066] Trial 85 finished with value: 0.9407023353084698 and parameters: {'classifier': 'RandomForest', 'n_estimators': 350, 'max_depth': 34.62727738972507}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:48,122] Trial 86 finished with value: 0.6373591262925525 and parameters: {'classifier': 'SVC', 'svc_c': 7144178.346161648}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:50,400] Trial 87 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 490, 'max_depth': 45.46424656486666}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:51,871] Trial 88 finished with value: 0.9494887881956547 and parameters: {'classifier': 'RandomForest', 'n_estimators': 300, 'max_depth': 10.867836329761642}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:56,814] Trial 89 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1060, 'max_depth': 47.53179221582363}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:58:57,910] Trial 90 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 230, 'max_depth': 50.083065944043035}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:02,848] Trial 91 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1060, 'max_depth': 43.43553580841346}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:04,801] Trial 92 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 420, 'max_depth': 10.025831201399505}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:06,351] Trial 93 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 330, 'max_depth': 46.97931192732663}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:08,221] Trial 94 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 10.561075547589365}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:09,551] Trial 95 finished with value: 0.9472812826768909 and parameters: {'classifier': 'RandomForest', 'n_estimators': 280, 'max_depth': 11.83534488012344}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:11,010] Trial 96 finished with value: 0.9450883002207506 and parameters: {'classifier': 'RandomForest', 'n_estimators': 310, 'max_depth': 13.469426561583564}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:12,114] Trial 97 finished with value: 0.9494742651330311 and parameters: {'classifier': 'RandomForest', 'n_estimators': 230, 'max_depth': 52.71797777855043}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:13,258] Trial 98 finished with value: 0.945073777158127 and parameters: {'classifier': 'RandomForest', 'n_estimators': 240, 'max_depth': 14.305758987318704}. Best is trial 43 with value: 0.9538747531079353.
# [I 2021-09-25 10:59:15,624] Trial 99 finished with value: 0.9428953177646102 and parameters: {'classifier': 'RandomForest', 'n_estimators': 500, 'max_depth': 56.18046894410625}. Best is trial 43 with value: 0.9538747531079353.
# Accuracy: 0.9538747531079353
# Best hyperparameters: {'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 15.4148845494433}

# %%
trial
# Out:
# FrozenTrial(number=43, values=[0.9538747531079353], datetime_start=datetime.datetime(2021, 9, 25, 10, 56, 40, 989581), datetime_complete=datetime.datetime(2021, 9, 25, 10, 56, 42, 769136), params={'classifier': 'RandomForest', 'n_estimators': 380, 'max_depth': 15.4148845494433}, distributions={'classifier': CategoricalDistribution(choices=('RandomForest', 'SVC')), 'n_estimators': IntUniformDistribution(high=2000, low=200, step=10), 'max_depth': LogUniformDistribution(high=100.0, low=10.0)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=43, state=TrialState.COMPLETE, value=None)

# %%
study.best_params
# Out:
# {'classifier': 'RandomForest',
#  'max_depth': 15.4148845494433,
#  'n_estimators': 380}

# %%
rf=RandomForestClassifier(n_estimators=380,max_depth=15.4148845494433)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=15.4148845494433,
#                        max_features='auto', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=380, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
y_pred=rf.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[65  2]
#  [ 2 45]]
# 0.9649122807017544
#               precision    recall  f1-score   support
#
#            B       0.97      0.97      0.97        67
#            M       0.96      0.96      0.96        47
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
